# %%
import numpy as np
import pandas as pd

# %%
data_one = {'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']}

# %%
data_two = {'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']}

# %%
one = pd.DataFrame(data_one)

# %%
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one,two], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([two,one], axis=1)
# Out:
#     C   D   A   B
# 0  C0  D0  A0  B0
# 1  C1  D1  A1  B1
# 2  C2  D2  A2  B2
# 3  C3  D3  A3  B3

# %%
pd.concat([one,two], axis=0)
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two.columns = one.columns

# %%
two
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one,two], axis=0)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
newdf = pd.concat([one,two], axis=0)

# %%
newdf.index = range(len(newdf))

# %%
newdf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
#help(pd.merge)

# %%
pd.merge(registrations,logins, how='inner', on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(logins, registrations, how='inner', on='name')
# Out:
#    log_id    name  reg_id
# 0       2  Andrew       1
# 1       4    Bobo       2

# %%
pd.merge(registrations,logins, how='left', on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations,logins, how='right', on='name')
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins, how="outer", on='name')
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %%
registrations = registrations.set_index('name')

# %%
registrations
# Out:
#         reg_id
# name
# Andrew       1
# Bobo         2
# Claire       3
# David        4

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins, left_index=True, right_on='name', how="inner")
# Out:
#    reg_id  log_id    name
# 1       1       2  Andrew
# 3       2       4    Bobo

# %%
registrations = registrations.reset_index()

# %%
registrations.columns = ['reg_names', 'reg_ids']

# %%
registrations
# Out:
#   reg_names  reg_ids
# 0    Andrew        1
# 1      Bobo        2
# 2    Claire        3
# 3     David        4

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
res = pd.merge(registrations,logins, how='inner', left_on='reg_names', right_on='name')

# %%
res
# Out:
#   reg_names  reg_ids  log_id    name
# 0    Andrew        1       2  Andrew
# 1      Bobo        2       4    Bobo

# %%
res.drop('reg_names',axis=1)
# Out:
#    reg_ids  log_id    name
# 0        1       2  Andrew
# 1        2       4    Bobo

# %%
registrations.columns = ['name', 'id']

# %%
logins.columns = ['id', 'name']

# %%
registrations
# Out:
#      name  id
# 0  Andrew   1
# 1    Bobo   2
# 2  Claire   3
# 3   David   4

# %%
logins
# Out:
#    id     name
# 0   1   Xavier
# 1   2   Andrew
# 2   3  Yolanda
# 3   4     Bobo

# %%
pd.merge(registrations,logins, how='inner', on='name')
# Out:
#      name  id_x  id_y
# 0  Andrew     1     2
# 1    Bobo     2     4

# %%
pd.merge(registrations,logins, how='inner', on='name')
# Out:
#      name  id_x  id_y
# 0  Andrew     1     2
# 1    Bobo     2     4
