# %%
import numpy as np
import matplotlib.pylab as plt

# %%
a = np.linspace(0,10,11)
b = a ** 4

# %%
x= np.arange(0,10)
y= 2*x

# %%
fig, axes=plt.subplots(nrows=1,ncols=2)

# %%
# Out:
# <AxesSubplot: >

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2,)
